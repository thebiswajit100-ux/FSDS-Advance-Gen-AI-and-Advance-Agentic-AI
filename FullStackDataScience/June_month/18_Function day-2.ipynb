# %% [markdown]
# # 1. Positional Argument

# %%
def person(name, age):
    print(name)
    print(age)

person('nit')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 5
#       2     print(name)
#       3     print(age)
# ----> 5 person('nit')
#
# TypeError: person() missing 1 required positional argument: 'age'

# %%
def person(name):
    print(name)
    print(age)

person('nit', 23)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 5
#       2     print(name)
#       3     print(age)
# ----> 5 person('nit', 23)
#
# TypeError: person() takes 1 positional argument but 2 were given

# %%
def person(name, age):
    print(name)
    print(age)

person('nit', 23)
# Out:
# nit
# 23

# %%
def person(age, name):
    print(name)
    print(age)

person('nit', 23)
# Out:
# 23
# nit

# %%
def person(age, name):
    print(name)
    print(age+1)

person('nit', 23)
# Out:
# 23
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 5
#       2     print(name)
#       3     print(age+1)
# ----> 5 person('nit', 23)
#
# Cell In[14], line 3, in person(age, name)
#       1 def person(age, name):
#       2     print(name)
# ----> 3     print(age+1)
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# # 2. Keyword Argument

# %%
def person(age, name):
    print(name)
    print(age+1)

person('nit', 23)
# Out:
# 23
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 5
#       2     print(name)
#       3     print(age+1)
# ----> 5 person('nit', 23)
#
# Cell In[17], line 3, in person(age, name)
#       1 def person(age, name):
#       2     print(name)
# ----> 3     print(age+1)
#
# TypeError: can only concatenate str (not "int") to str

# %%
def person(age, name):
    print(name)
    print(age+1)

person(name='nit', age = 23)
# Out:
# nit
# 24

# %%
def person(age, name, mob):
    print(name)
    print(age + 1)
    print(mob)

person(name='nit', age = 23, 12345)
# Out:
#   Cell In[21], line 6
#     person(name='nit', age = 23, 12345)
#                                       ^
# SyntaxError: positional argument follows keyword argument

# %%
def person(age, name, mob):
    print(name)
    print(age+1)
    print(mob)

person(name='nit', age = 23, mob=12345)
# Out:
# nit
# 24
# 12345

# %% [markdown]
# # Default Argument

# %%
def person(name, age):
    print(name)
    print(age)

person('nit')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 5
#       2     print(name)
#       3     print(age)
# ----> 5 person('nit')
#
# TypeError: person() missing 1 required positional argument: 'age'

# %%
def person(name, age=18):
    print(name)
    print(age)

person('nit')
# Out:
# nit
# 18

# %%
def person(name, age = 20):
    print(name)
    print(age)

person('nit')
# Out:
# nit
# 20

# %% [markdown]
# # Variable Length Argument

# %%
def sum(a, b):
    c = a + b
    print(c)

sum(5, 6)
# Out:
# 11

# %%
def sum(a, b):
    c = a + b
    print(c)

sum(5, 6, 7, 8)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 5
#       2     c = a + b
#       3     print(c)
# ----> 5 sum(5, 6, 7, 8)
#
# TypeError: sum() takes 2 positional arguments but 4 were given

# %%
def sum(a , *b):
    c = a + b
    print(c)

sum(5, 6, 7, 8)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 5
#       2     c = a + b
#       3     print(c)
# ----> 5 sum(5, 6, 7, 8)
#
# Cell In[39], line 2, in sum(a, *b)
#       1 def sum(a , *b):
# ----> 2     c = a + b
#       3     print(c)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'tuple'

# %%
def sum(a, *b): # 1st argument is fixed but for 2nd argument

    print(type(a))
    print(type(b))

    print(a)
    print(b)

sum(5, 6, 7, 8)
# Out:
# <class 'int'>
# <class 'tuple'>
# 5
# (6, 7, 8)

# %%
# 1st argument is fixed & we fetch each value from the tupel & we can add them.

def sum(a, *b): 
    c = a

    for i in b:
        c = c + i
    print(c)

sum(5, 6, 7, 8)
# Out:
# 26

# %%
# 1st argument is fixed & we fetch each value from the tuple & we can add them.

def sum(a, *b):
    c = a

    for i in b:
        c = c + i
    print(c)

sum(5, 6, 7, 8, 9, 10, -1, -2, 100)
# Out:
# 142

# %% [markdown]
# # KWARGS ( KW + ARGS )

# %%
def person(name, *data):
    print(name)
    print(data)

person('ALEX', 36, 'JOHN', 987767)
# Out:
# ALEX
# (36, 'JOHN', 987767)

# %%
def person(name, * data):
    print(name)
    print(data)

person('ALEX', 36, 'JOHN', 987767)
# Out:
# ALEX
# (36, 'JOHN', 987767)

# %%
def person(name, *data):
    print('name')
    print(data)

person('ALEX', age = 36, home_place = 'southcity', mob = 987767)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[52], line 5
#       2     print('name')
#       3     print(data)
# ----> 5 person('ALEX', age = 36, home_place = 'southcity', mob = 987767)
#
# TypeError: person() got an unexpected keyword argument 'age'

# %%
def person(name, **data):
    print('name')
    print(data)

person('ALEX', age=36, home_place = 'southcity', mob=987767)
# Out:
# name
# {'age': 36, 'home_place': 'southcity', 'mob': 987767}
