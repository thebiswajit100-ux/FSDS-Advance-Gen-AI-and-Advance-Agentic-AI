# %% [markdown]
# ## **EDA** (Explaratory data analysis)
#
# * eda foundation to become a machine learning developer
# * if you are not understand eda then -- hard to build ml model
# * if you not build ml model -- then mlops will not understand
# * mlops not understand - cicd pipline you never build
#
#
# ### **EDA Technique -->**
#
# **1- variable identification**
#                          Independent variable  (non target | non predictive) -- x
#                          dependent variable (target | predictive) - y
#
# **2 - univariate analysis**
#
# **3 - bivariate analysis**
#
# **4 - outlier treatment**
#
# **5 - missing value treatment**
#
# **6 - imputation technique ( transformer)**
#
# **7 - new variable creation**
#
#
# #### **1. variable identification**
#
#                        column names = feature == attribute
#
#    * father | employ -- DEPENDENT VARAIABLE = TARGET ATTRIBUTE == PREDICTED VARAIABLE (Y)
#
#    * mom | housewife -- iNDEPENDENT VARIABLE == NON TARGET ATTRIBUTE == NON PREDICTED VARAIBLE (X1)
#
#    * son | 3rd grade - INDEPENDENT VARIABLE == NON TARGET ATTRIBUTE == NON PREDICTED VARIABLE (X2)
#
#    * daughter - 2nd grade -- INDEPENDENT VARIABLE == NON TARGET ATTRIBUTE == NON PREDICTED VARIABLE (X3)
#
#    **Y = X1 + X2 + X3**
#
#    **Y = m1x1 + m2x2 + m3x3 -- multiple linear regression algorithm**
#
# ====
#       **dv(dependent variable) is continuous == regression concept**
#
# #### **what is mean by continuous ?**
#       gold price
#
#       petrol price
#
#       stock price
#
#       ev price
#
#       monthly electricity price
#
#       flight price
#
#       train ticket price
#
#       bus ticket price
#
#       hotel price
#
#       employ salary
#
#       land price prediction
#
# #### **To build these above project we need to implement regression algorithm**
#
# 1 - simple liner regression alogrithm
#
# 2 - multiple linear regression algorithm
#
# 3 - gradient descend algorithm
#
# 4 - stocasting gradient descend algo
#
# 5 - batch gradient descend algorithm
#
# 6 - lasso regularization | l1 regularization | l1 regression
#
# 7 - ridge regularization | l2 regularization | l2 regression
#
# 8 - polynomial regression alogrithm
#
# 9 - k nearest neighbour regression algorithm
#
# 10 - support vectore regression algorithm
#
# 11 - decission tree regression algorithm
#
# 12 - random forest regression
#
# 13 - xgboost (xtream  greadient boostin)
#
# 14 - lgbm (light gradient boosting)
#
# 15 - time series algorithm
#
# 16 - artificial neural network regression
#
# #### **MACHINE LEARNING**
#
# - supervised learning (REGRESSION -- DEPENDENT variable is continous | continuous variable
# - supervised learning (CLASSIFICATION -- Depedent variable is binary | binary variable
# - unsupervised learning (CLUSTERING -- no dependent variable  if is discrest discrete| variable
#
#
# **CLASSIFICATION** - dv (Dependent variable) is binaray
#                                 pass | fail
#
#                                 profit | loss
#
#                                 spam | non spam
#
#                                 tasty | not tasty
#
#                                 studnt | not study
#
#                                 up | down
#
#                                 purchase | non purchase
#
#                                 male | female
#
#                                 yes | no
#
#                                 win | loss
#
# ----
# #### **classification algorithm** -->
# ----
#
# 1 - logistic regression
#
# 2 - support vector machine
#
# 3 - knn classifier
#
# 4 - naive bayes algorithm (baysian theorm)
#
# 5 - decission tree
#
# 6 - random forest
#
# 7 - xgboost
#
# 8 - lgbm
#
# 9 - ann classifier
#
# ----
# #### **CLUSTERING -- grouping ( no dependent variable)**
# ----
#
# 1 - pca ( principal component analysis)
#
# 2 - k means clustering
#
# 3 - hierarchical clustering
#
# 4 - dbscan
#
# All ml model are automized by agentic AI
#
# #### **multicollnieartity or overfitting problem hear**
#
# 1 - variable identification
#                            - independent variable (x1, x2, x3 --------- xn)
#                            - dependent variable (y)
#                            - non relavant attribute
#                            - realvant attribute
# Note : Every time while build ml model we must has to look on relavant attributes or else overfitting problem will happened
#
# 2 - unvariant analysis -- plot the graph using 1 variable
#
# 3 - outlier treatment
#
# 4 -  bivariate analysis
