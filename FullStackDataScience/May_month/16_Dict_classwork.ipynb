# %% [markdown]
# Dictionary

# %% [raw]
# 1) Dictionary is a mutable data type in Python.
# 2) A python dictionary is a collection of key and value pairs separated by a colon (:) &
#    enclosed in curly braces {}.
# 3) Keys must be unique in a dictionary, duplicate values are allowed.

# %% [markdown]
# Create Dictionary

# %%
mydict = dict() # Empty dictionary
mydict
# Out:
# {}

# %%
mydict = {}  # empty dictionary
mydict
# Out:
# {}

# %%
mydict = {1:'one', 2:'two', 3:'three'} # dictionary with integer keys
mydict
# Out:
# {1: 'one', 2: 'two', 3: 'three'}

# %%
mydict = dict({1:'one',2:'two',3:'three'})  # create dictionary using dict()
mydict
# Out:
# {1: 'one', 2: 'two', 3: 'three'}

# %%
mydict = {'A':'one', 'B':'two', 'C':'three'}  # dictionary with character keys
mydict
# Out:
# {'A': 'one', 'B': 'two', 'C': 'three'}

# %%
mydict = {1:'one', 'A':'two', 3:'three'}  # dictionary with mixed keys
mydict
# Out:
# {1: 'one', 'A': 'two', 3: 'three'}

# %%
mydict.keys()  # Returns Dictionary keys using keys() method
# Out:
# dict_keys([1, 'A', 3])

# %%
mydict.values() # Returns Dictionary Values using values() method
# Out:
# dict_values(['one', 'two', 'three'])

# %%
mydict.items() # Access each key-value pair within a dictionary
# Out:
# dict_items([(1, 'one'), ('A', 'two'), (3, 'three')])

# %%
mydict = {1:'one', 2:'two', 'A':['asif', 'john', 'Maria']}
mydict
# Out:
# {1: 'one', 2: 'two', 'A': ['asif', 'john', 'Maria']}

# %%
mydict.items()
# Out:
# dict_items([(1, 'one'), (2, 'two'), ('A', ['asif', 'john', 'Maria'])])

# %%
mydict.keys()
# Out:
# dict_keys([1, 2, 'A'])

# %%
mydict.values()
# Out:
# dict_values(['one', 'two', ['asif', 'john', 'Maria']])

# %%
mydict = {1:'one', 2:'two', 'A':['asif', 'john', 'Maria'], 'B':('Bat', 'cat', 'hat')}
mydict
# Out:
# {1: 'one',
#  2: 'two',
#  'A': ['asif', 'john', 'Maria'],
#  'B': ('Bat', 'cat', 'hat')}

# %%
mydict = {1:'one', 2:'two', 'A':{'Name':'asif' , 'Age':20}, 'B':('Bat' , 'cat', 'hat')}

# %%
mydict
# Out:
# {1: 'one',
#  2: 'two',
#  'A': {'Name': 'asif', 'Age': 20},
#  'B': ('Bat', 'cat', 'hat')}

# %%
keys = {'a', 'b', 'c', 'd'}
mydict3 = dict.fromkeys(keys)    # create a dictionary from a sequence of keys
mydict3
# Out:
# {'a': None, 'b': None, 'c': None, 'd': None}

# %%
keys = {'a', 'b', 'c', 'd'}
value = [10,20,30]
mydict3 = dict.fromkeys(keys,value)  # create a dictionary from a sequence of value
mydict3
# Out:
# {'a': [10, 20, 30], 'b': [10, 20, 30], 'c': [10, 20, 30], 'd': [10, 20, 30]}

# %%
value.append(40)
mydict3
# Out:
# {'a': [10, 20, 30, 40],
#  'b': [10, 20, 30, 40],
#  'c': [10, 20, 30, 40],
#  'd': [10, 20, 30, 40]}

# %% [markdown]
# Accessing Items

# %%
mydict = {1:'one', 2:'two', 3:'three', 4:'four'}
mydict
# Out:
# {1: 'one', 2: 'two', 3: 'three', 4: 'four'}

# %%
mydict[1] # Access items using key
# Out:
# 'one'

# %%
mydict.get(1)  # Access item using get() method
# Out:
# 'one'

# %%
mydict1 = {'Name':'Asif', 'ID': 74123, 'DOB': 1991, 'job':'Analyst'}
mydict1
# Out:
# {'Name': 'Asif', 'ID': 74123, 'DOB': 1991, 'job': 'Analyst'}

# %%
mydict1['Name']  # Access item using key
# Out:
# 'Asif'

# %%
mydict1.get('job')  # Access item  using get() method
# Out:
# 'Analyst'

# %% [markdown]
# Add, Remove & Change Items

# %%
mydict1 = {'Name':'Asif', 'ID':12345, 'DOB':1991, 'Address':'Hilsinki'}
mydict1
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1991, 'Address': 'Hilsinki'}

# %%
mydict1['DOB'] = 1992 # Changing Dictionary Items
mydict1['Address'] = 'Delhi'
mydict1
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1992, 'Address': 'Delhi'}

# %%
dict1 = {'DOB':1995}
mydict1.update(dict1)
mydict1
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1995, 'Address': 'Delhi'}

# %%
mydict1['Job'] = 'Analyst' # Adding items in the dictionary
mydict1
# Out:
# {'Name': 'Asif',
#  'ID': 12345,
#  'DOB': 1995,
#  'Address': 'Delhi',
#  'Job': 'Analyst'}

# %%
mydict1.pop('Job') # Removing items in the dictionary using pop method
mydict1
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1995, 'Address': 'Delhi'}

# %%
mydict1.popitem() # A random item is removed
# Out:
# ('Address', 'Delhi')

# %%
mydict1
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1995}

# %%
del[mydict1['ID']]  # Removing item using del method
mydict1
# Out:
# {'Name': 'Asif', 'DOB': 1995}

# %%
mydict1.clear() # Delete all items of the dictionary using clear method 
mydict1
# Out:
# {}

# %%
del mydict1 # Delete the dictionary object
mydict1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[74], line 2
#       1 del mydict1 # Delete the dictionary object
# ----> 2 mydict1
#
# NameError: name 'mydict1' is not defined

# %% [markdown]
# Copy Dictionary

# %%
mydict = {'Name':'Asif', 'ID':12345, 'DOB':1991, 'Address':'Hilsinki'}
mydict
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1991, 'Address': 'Hilsinki'}

# %%
mydict1 =  mydict # Create a new reference "mydict1"

# %%
id(mydict), id(mydict1) # The address of both mydict & mydict1 will be the same
# Out:
# (2379782502016, 2379782502016)

# %%
mydict2 = mydict.copy() # create a copy of the dictionary

# %%
id(mydict2) # The address of mydict2 will be different from mydict
# Out:
# 2379782639744

# %%
mydict['Address'] = 'Mumbai'

# %%
mydict
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1991, 'Address': 'Mumbai'}

# %%
mydict1 # mydict1 will be also impacted as it is pointing the same dictionary
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1991, 'Address': 'Mumbai'}

# %%
mydict2 # copy of list won't be impacted due to the changes made in the original dictionary
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1991, 'Address': 'Hilsinki'}

# %% [markdown]
# Loop through a Dictionary

# %%
mydict1 = {'Name':'Asif', 'ID':12345, 'DOB':1991, 'Address':'Hilsinki', 'Job':'Analyst'}
mydict1
# Out:
# {'Name': 'Asif',
#  'ID': 12345,
#  'DOB': 1991,
#  'Address': 'Hilsinki',
#  'Job': 'Analyst'}

# %%
for i in mydict1:
    print(i, ':' , mydict1[i]) # key & value pair
# Out:
# Name : Asif
# ID : 12345
# DOB : 1991
# Address : Hilsinki
# Job : Analyst

# %%
for i in mydict1:
    print(mydict1[i]) # Dictionary items
# Out:
# Asif
# 12345
# 1991
# Hilsinki
# Analyst

# %% [markdown]
# Dictionary Membership

# %%
mydict1 = {'Name':'Asif', 'ID':12345, 'DOB':1991, 'Job':'Analyst'}
mydict1
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1991, 'Job': 'Analyst'}

# %%
'Name' in mydict1 # Test if a key is in a dictionary or not.
# Out:
# True

# %%
'Asif' in mydict1  # Membership test can be only done for keys.
# Out:
# False

# %%
'ID' in mydict1
# Out:
# True

# %%
'Address' in mydict1
# Out:
# False

# %% [markdown]
# All / Any

# %% [raw]
# The all() method returns:
#   1) True - if all the keys of the dictionary are true
#   2) False - if any key of the dictionary is false
# The any() function returns True if any key of the dictionary is True. If not, any() returns False.

# %%
mydict1 = {'Name':'Aisf', 'ID':12345, 'DOB':1991, 'Job':'Analyst'}
mydict1
# Out:
# {'Name': 'Aisf', 'ID': 12345, 'DOB': 1991, 'Job': 'Analyst'}

# %%
all(mydict1) # Will Return false as one value is false (Value 0)
# Out:
# True

# %% [markdown]
# Print()

# %%
# print is use for answer

# %%
a = 10
b = 20
a
b
# Out:
# 20

# %%
a = 10
b = 20
print(a)
print(b)
# Out:
# 10
# 20

# %%
print(10)
print(10,20)
print('python')
print(10,20,'python')
# Out:
# 10
# 10 20
# python
# 10 20 python

# %%
num1 = 20
num2 = 30
add = num1 + num2
print(add)
# Out:
# 50

# %% [markdown]
# print result with string

# %%
num1 = 20
num2 = 30
add = num1+num2
print('The addition of', num1,'add', num2,'is=',add)
# Out:
# The addition of 20 add 30 is= 50

# %%
name = 'Python'
age = 20
city = 'hyd'
#hellow my name is python and i am 10 year old from hyderabad

# %%
print('My name is',name,'and i am ',age,'year old from',city)
# Out:
# My name is Python and i am  20 year old from hyd

# %% [markdown]
# Print Format method

# %%
num1 = 20
num2 = 30
add = num1 + num2
print('The addition of {} and {} is= {}'.format(num1,num2,add))
# Out:
# The addition of 20 and 30 is= 50

# %% [raw]
# 1) first decide how the print statement should be
# 2) like:- THe addition of 20 and 30 is = 50
# 3) then replace the variable position with curly braces{}
# 4) the apply .format(val1,val2,.....val-n methodm

# %%
name = 'Python'
age = 20
city = 'hyd'
# helllow my name is python and i am 10 year old form hyderabad

# %%
print('hello my name is {}, and i am {} years old from {}'.format(name,age,city))
# Out:
# hello my name is Python, and i am 20 years old from hyd

# %%
num1 = 100
num2 = 25
num3 = 333
avg = (num1 + num2 + num3) / 3 # or we can use avg=round(num1+num2+num3)/3,2)
avg1 = round((num1+num2+num3)/3,2)
# The average of num1,num2,num3 is = avg

print('The average of {},{},and {} is = {} or {}'.format(num1,num2,num3,avg,avg1))
# Out:
# The average of 100,25,and 333 is = 152.66666666666666 or 152.67

# %%
round(avg,2) # round of till 2 digit after decimal
# Out:
# 152.67

# %% [markdown]
# More short format method(f string method)

# %% [raw]
# 1) variable should be in curyl braces
# 2) and write everythin inside quots ''
# 3) at starting simply add f

# %%
num1 = num1 + num2
print(f'The addition of {num1} and {num2} is= {add}') # always prefer this
# Out:
# The addition of 125 and 25 is= 50

# %%
name = 'Python'
age = 20
city = 'hyd'
# hellow my name is python and i am 10 year old from hyderabad

# %%
print(f'hello my name is {name}, and i am {age} years old from {city}.')
# Out:
# hello my name is Python, and i am 20 years old from hyd.

# %%
num1 = 100
num2 = 25
num3 = 333
avg = round((num1+num2+num3)/3,2) 
avg
# The average of num1, num2,num3 is = avg
# Out:
# 152.67

# %%
print(f'The average of {num1}, {num2}, and {num3} is = {avg}')
# Out:
# The average of 100, 25, and 333 is = 152.67

# %%
# let combine all
num1 = 10
num2 = 20
add = num1 + num2
print('The additon of',num1,'and',num2,'is=',add)
print('The addition of {} and {} is= {}'.format(num1,num2,add))
print(f'The additon of {num1} and {num2} is= {add}')
# Out:
# The additon of 10 and 20 is= 30
# The addition of 10 and 20 is= 30
# The additon of 10 and 20 is= 30

# %% [markdown]
# end statement

# %%
print('hello')  # 1st statement
print('good morning') # 2nd statement
# I want to print like: Hello good morning
# Out:
# hello
# good morning

# %% [raw]
# Here we will use end statement that joint line from end of one string to starting of other string

# %%
print('hello', end=' ') # 1st statement
print('world good day') # 2nd statement
# Out:
# hello world good day

# %% [markdown]
# separator

# %% [raw]
# 1) Here one print statement only we use
# 2) inside one print statement we have multiple values
# 3) we want to separate these mutiple values with anything

# %%
print('hello','hai','how are you',sep='--->')
# Out:
# hello--->hai--->how are you

# %%
print('hello','hai','how are you',sep='&')
# Out:
# hello&hai&how are you

# %%
print('hello','hai','how are you',sep='@')
# Out:
# hello@hai@how are you

# %%
print('hello','hai','how are you',sep=' ')
# Out:
# hello hai how are you

# %%
print(3,'.') # . is far from 3 so here we will use sep method
# Out:
# 3 .

# %%
print(3,'.',sep='') # see now sapce setteld (also use to remove space B/W words)
# Out:
# 3.

# %%
print(1,2,end=' ')
print(3,'.',sep='')
# will print 1 2 3.
# Out:
# 1 2 3.
