# %%
l = []
l1 = [10, 20, 30, 40, 50, 60, 10, 'prakash senapati']
l2 = [34, 5.3, 'prakash', (1+2j), True]

# %%
print(l)
print(l1)
print(l2)
# Out:
# []
# [10, 20, 30, 40, 50, 60, 10, 'prakash senapati']
# [34, 5.3, 'prakash', (1+2j), True]

# %%
l.extend(l2)
# Out:
# [34, 5.3, 'prakash', (1+2j), True, 34, 5.3, 'prakash', (1+2j), True]

# %%
print(l)
# Out:
# [34, 5.3, 'prakash', (1+2j), True, 34, 5.3, 'prakash', (1+2j), True]

# %%
l.clear()

# %%
l
# Out:
# []

# %%
l.extend(l2)

# %%
print(l)
# Out:
# [34, 5.3, 'prakash', (1+2j), True]

# %%
l.extend(l1)
l
# Out:
# [34,
#  5.3,
#  'prakash',
#  (1+2j),
#  True,
#  10,
#  20,
#  30,
#  40,
#  50,
#  60,
#  10,
#  'prakash senapati']

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 10, 'prakash senapati']

# %%
l1.append(10)

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 10, 'prakash senapati', 10]

# %%
l1.index(10)
# Out:
# 0

# %%
l1.index('prakash senapati')
# Out:
# 7

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 10, 'prakash senapati', 10]

# %%
l1.insert(2,25)
l1
# Out:
# [10, 20, 25, 30, 40, 50, 60, 10, 'prakash senapati', 10]

# %%
l1.pop()
l1
# Out:
# [10, 20, 25, 30, 40, 50, 60, 10, 'prakash senapati']

# %%
l1.pop()
# Out:
# 'prakash senapati'

# %%
l1
# Out:
# [10, 20, 25, 30, 40, 50, 60, 10]

# %%
l
# Out:
# [34,
#  5.3,
#  'prakash',
#  (1+2j),
#  True,
#  10,
#  20,
#  30,
#  40,
#  50,
#  60,
#  10,
#  'prakash senapati']

# %%
l.pop()
# Out:
# 'prakash senapati'

# %%
l.pop()
# Out:
# 10

# %%
l
# Out:
# [34, 5.3, 'prakash', (1+2j), True, 10, 20, 30, 40, 50, 60]

# %%
l.pop(2)
# Out:
# 'prakash'

# %%
l
# Out:
# [34, 5.3, (1+2j), True, 10, 20, 30, 40, 50, 60]

# %%
l[3]
# Out:
# True

# %%
l
# Out:
# [34, 5.3, (1+2j), True, 10, 20, 30, 40, 50, 60]

# %%
l.remove(1+2j)

# %%
l
# Out:
# [34, 5.3, True, 10, 20, 30, 40, 50, 60]

# %%
l.reverse()

# %%
l
# Out:
# [60, 50, 40, 30, 20, 10, True, 5.3, 34]

# %%
l
# Out:
# [60, 50, 40, 30, 20, 10, True, 5.3, 34]

# %%
l.reverse()

# %%
l
# Out:
# [34, 5.3, True, 10, 20, 30, 40, 50, 60]

# %%
print(l)
print(l1)
print(l2)
# Out:
# [34, 5.3, True, 10, 20, 30, 40, 50, 60]
# [10, 20, 25, 30, 40, 50, 60, 10]
# [34, 5.3, 'prakash', (1+2j), True]

# %%
l2.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 l2.sort()
#
# TypeError: '<' not supported between instances of 'str' and 'float'

# %%
l
# Out:
# [34, 5.3, True, 10, 20, 30, 40, 50, 60]

# %%
l1
# Out:
# [10, 20, 25, 30, 40, 50, 60, 10]

# %%
l1.sort()

# %%
l1
# Out:
# [10, 10, 20, 25, 30, 40, 50, 60]

# %%
l1.sort(reverse= True)

# %%
l1
# Out:
# [60, 50, 40, 30, 25, 20, 10, 10]

# %%
l2
# Out:
# [34, 5.3, 'prakash', (1+2j), True]

# %%
l3 = [3, 1, 2]
l3
# Out:
# [3, 1, 2]

# %%
l3.sort() # parameter tunning
l3
# Out:
# [1, 2, 3]

# %%
l3.sort(reverse= True)
l3
# Out:
# [3, 2, 1]

# %%
l1
# Out:
# [60, 50, 40, 30, 25, 20, 10, 10]

# %%
l2
# Out:
# [34, 5.3, 'prakash', (1+2j), True]

# %%
l2[2]
# Out:
# 'prakash'

# %%
l2[2][0]
# Out:
# 'p'

# %%
print(l2[2][0])
print(l2[2][1])
print(l2[2][2])
print(l2[2][3])
print(l2[2][4])
print(l2[2][5])
# Out:
# p
# r
# a
# k
# a
# s

# %%
l
# Out:
# [34, 5.3, True, 10, 20, 30, 40, 50, 60]

# %%
for i in l:
    print(i)
# Out:
# 34
# 5.3
# True
# 10
# 20
# 30
# 40
# 50
# 60

# %%
for i in enumerate(l):
    print(i)
# Out:
# (0, 34)
# (1, 5.3)
# (2, True)
# (3, 10)
# (4, 20)
# (5, 30)
# (6, 40)
# (7, 50)
# (8, 60)

# %%
l1
# Out:
# [60, 50, 40, 30, 25, 20, 10, 10]

# %%
l1.sort()

# %%
l1
# Out:
# [10, 10, 20, 25, 30, 40, 50, 60]

# %%
all(l1)
# Out:
# True

# %%
any(l1)
# Out:
# True

# %%
l1.append(0)

# %%
l1
# Out:
# [10, 10, 20, 25, 30, 40, 50, 60, 0]

# %%
all(l1)
# Out:
# False

# %%
any(l1)
# Out:
# True

# %%
l4 = []

# %%
all(l4)
# Out:
# True

# %%
any(l4)
# Out:
# False
