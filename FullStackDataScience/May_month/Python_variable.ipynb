# %%
# Example 1: Integer Variable
age = 25 # Here, 'age' is a variable , and it stores an integer value 25
print(age)
# Out:
# 25

# %%
#Example 2: String Variable
name = "Alice" # 'name is a variable, storing a string "Alice"
print(name)
# Out:
# Alice

# %%
#Example 3: Float Variable
price = 19.99 #'price' is a variable, storing a floating-point number
print(price)
# Out:
# 19.99

# %%
#Example 4: Boolean Variable
is_active = True # 'is_active' is a variable, storing a Boolean Value
print(is_active)
# Out:
# True

# %%
# storing the value 10 in a variable callled 'x'
x = 10
#printing the value of 'x'
print(x)
# Out:
# 10

# %%
#Assigning values to variables
a = 5
b = 3
# Adding two variables and storing the result in 'result'
result = a + b
print(result)
# Out:
# 8

# %%
# Initial value
score = 50
print(score)

# changing the value of 'score'
score = 100
print(score)
# Out:
# 50
# 100

# %%
# Assigning values to variables
first_name = "John"
last_name = "Doe"

# Concatenating strings and storing in a new variable
full_name = first_name + " " + last_name
print(full_name) #output: John Doe
# Out:
# John Doe

# %%
# Assigning values to variables
length = 10
width = 5

#calculating the area of a rectangle
area = length * width
print(area)
# Out:
# 50

# %%
x = 10 # Initial value of x
print(x)

#Reassigning the value of x
x = 20
print(x)
# Out:
# 10
# 20

# %%
# variables in Python

first_name = 'PRAKASH'
last_name = 'SENAPATI'
country = 'HYD'
city = 'TELENGANA'
age = 40087
is_married = True
skills = ['HTML', 'CSS', 'JS', 'React', 'Python']
person_info = {
    'firstname':'Asabeneh',
    'lastname':'Yetayeh',
    'country':'Finland',
    'city':'Helsinki'
    }

#printing the values stored in the variables

print('First name:' , first_name)
print('First name length:', len(first_name))
print('Last name: ', last_name)
print('Last name length:', len(last_name))
print('country:' , country)
print('city:', city)
print('Age: ', age)
print('Married:', is_married)
print('skills:' , skills)
print('preson information:' , person_info)


# Declaring multiple variables in one line

first_name, last_name, country, age , is_married = 'prakash','senapati', 'Helsink', 250, True

print(first_name, last_name, country, age , is_married)
print('first name:', first_name)
print('Last name: ', last_name)
print('country:', country)
print('Age:', age)
print('Married:', is_married)
# Out:
# First name: PRAKASH
# First name length: 7
# Last name:  SENAPATI
# Last name length: 8
# country: HYD
# city: TELENGANA
# Age:  40087
# Married: True
# skills: ['HTML', 'CSS', 'JS', 'React', 'Python']
# preson information: {'firstname': 'Asabeneh', 'lastname': 'Yetayeh', 'country': 'Finland', 'city': 'Helsinki'}
# prakash senapati Helsink 250 True
# first name: prakash
# Last name:  senapati
# country: Helsink
# Age: 250
# Married: True
