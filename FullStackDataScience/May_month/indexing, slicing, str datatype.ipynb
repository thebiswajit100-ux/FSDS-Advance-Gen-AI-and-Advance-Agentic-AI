# %%
s = welcome
s
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 s = welcome
#       2 s
#
# NameError: name 'welcome' is not defined

# %%
True
# Out:
# True

# %%
true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 true
#
# NameError: name 'true' is not defined

# %%
s = 'welcome'

# %%
s
# Out:
# 'welcome'

# %%
id(s)
# Out:
# 2134833843296

# %%
len(s)
# Out:
# 7

# %%
s2 = ''' welcome
            to
               nit technology'''

# %%
s2
# Out:
# ' welcome\n            to\n               nit technology'

# %%
s4 = 'welcome'
s4
# Out:
# 'welcome'

# %%
print(s)
print(s4)
# Out:
# welcome
# welcome

# %%
print(id(s))
print(id(s4))
# Out:
# 2134833843296
# 2134833843296

# %%
s
# Out:
# 'welcome'

# %%
s[0] #forward index
# Out:
# 'w'

# %%
s[6]
# Out:
# 'e'

# %%
s[4]
# Out:
# 'o'

# %%
len(s)
# Out:
# 7

# %%
s[7]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 s[7]
#
# IndexError: string index out of range

# %%
s
# Out:
# 'welcome'

# %%
s[-1]
# Out:
# 'e'

# %%
s[-3]
# Out:
# 'o'

# %%
s
# Out:
# 'welcome'

# %%
s[-5]
# Out:
# 'l'

# %%
s[-10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 s[-10]
#
# IndexError: string index out of range

# %%
s
# Out:
# 'welcome'

# %%
s[:]
# Out:
# 'welcome'

# %%
s
# Out:
# 'welcome'

# %%
s[1:6]
# Out:
# 'elcom'

# %%
s
# Out:
# 'welcome'

# %%
s[:7]
# Out:
# 'welcome'

# %%
s[:5]
# Out:
# 'welco'

# %%
s[:100]
# Out:
# 'welcome'

# %%
s[1000:]
# Out:
# ''

# %%
s
# Out:
# 'welcome'

# %%
s[-1:]
# Out:
# 'e'

# %%
s
# Out:
# 'welcome'

# %%
s[-6:]
# Out:
# 'elcome'

# %%
s
# Out:
# 'welcome'

# %%
s[-7:-4] #backward slicing
# Out:
# 'wel'

# %%
import sys
import keyword
import operator
from datetime import datetime
import os

# %%
print(keyword.kwlist) # list all pythonn keywords
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
1var = 10 # Identifier can't start with a digit
# Out:
#   Cell In[87], line 1
#     1var = 10 # Identifier can't start with a digit
#     ^
# SyntaxError: invalid decimal literal

# %%
val2@ = 35 # Identifier can't use special symbols
# Out:
#   Cell In[89], line 1
#     val2@ = 35 # Identifier can't use special symbols
#           ^
# SyntaxError: invalid syntax

# %%
import = 125 #keyword can't be used to identifiers
# Out:
#   Cell In[91], line 1
#     import = 125 #keyword can't be used to identifiers
#            ^
# SyntaxError: invalid syntax

# %%
"""
correct way of defining an identifier
(Identifiers can be a combination of letters in lowercase (a to z) or uppercase
"""
val2 = 10
val_ = 99

# %% [markdown]
# Comments in python

# %% [raw]
# comments can be used to explain the code for more readability.

# %%
# Single line comment
val1 = 10

# %%
# Multiple
# line 
# comment
val1 = 10

# %%
'''
Multiple 
line 
comment
'''
val1 = 10

# %%
"""
Multiple
line 
comment
"""
val1 = 10

# %% [markdown]
# Statements

# %% [raw]
# Instructions that a python interpreter can execute

# %%
p = 20 # created an integer object with value 20 and assigns the variable p to p
q = 20 # create new reference q which will point to value 20. p & q will be point
r = q # variable r will also point to the same location where p & q are pointing
p, type(p), hex(id(p))
# Out:
# (20, int, '0x7ff978a82c18')

# %%
q , type(q), hex(id(q))
# Out:
# (20, int, '0x7ff978a82c18')

# %%
r, type(r), hex(id(r))
# Out:
# (20, int, '0x7ff978a82c18')

# %%
p = 20
p = p + 10 # variable overwriting
p
# Out:
# 30

# %% [markdown]
# Variable Assignment

# %%
intvar = 10 # Integer variable
floatvar = 2.57 #float variable
strvar = "Python Language" # String variable

print(intvar)
print(floatvar)
print(strvar)
# Out:
# 10
# 2.57
# Python Language

# %% [markdown]
# Multiple Assignments

# %%
intvar, floatvar, strvar = 10, 2.57, "Python Language" #using commas to separate
print(intvar)
print(floatvar)
print(strvar)
# Out:
# 10
# 2.57
# Python Language

# %%
p1 = p2 = p3 = p4 = 44 # All variables pointing to same value
print(p1,p2,p3,p4)
# Out:
# 44 44 44 44

# %% [markdown]
# Data Types

# %% [raw]
# Numeric

# %%
val1 = 10 # Integer data type
print(val1)
print(type(val1)) # type of object
print (sys.getsizeof(val1)) # size of intege object in bytes
print(val1, " is Integer?", isinstance(val1, int)) # val1 is an instance of integer
# Out:
# 10
# <class 'int'>
# 28
# 10  is Integer? True

# %%
val2 = 92.78 # Float data type
print(val2)
print(type(val2)) # type of object
print(sys.getsizeof(val2)) # size of float object in bytes
print(val2, " is float?", isinstance(val2, float)) # val2 is an instance of float
# Out:
# 92.78
# <class 'float'>
# 24
# 92.78  is float? True

# %%
val3 = 25 + 10j # Complex data type
print(val3)
print(type(val3)) # type of object
print(sys.getsizeof(val3)) # size of float object in bytes
print(val3," is complex?", isinstance(val3, complex)) # val3 is an instance of complex
# Out:
# (25+10j)
# <class 'complex'>
# 32
# (25+10j)  is complex? True

# %%
sys.getsizeof(int()) # size of integer object in bytes
# Out:
# 24

# %%
sys.getsizeof(float()) # size of float object in bytes
# Out:
# 24

# %%
sys.getsizeof(complex()) # size of complex object in bytes
# Out:
# 32

# %% [markdown]
# Boolean

# %% [raw]
# Boolean data type can have only two possible values true or false

# %%
bool1 = True

# %%
bool2 = False

# %%
print(type(bool1))
# Out:
# <class 'bool'>

# %%
print(type(bool2))
# Out:
# <class 'bool'>

# %%
isinstance(bool1, bool)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(1)
# Out:
# True

# %%
bool(None)
# Out:
# False

# %%
bool (False)
# Out:
# False

# %% [markdown]
# Strings

# %% [markdown]
# String Creation

# %%
str1 = "HELLO PYTHON"
print(str1)
# Out:
# HELLO PYTHON

# %%
mystr = 'Hello World' # Define string using single quotes
print(mystr)
# Out:
# Hello World

# %%
mystr = "Hello World" # Define string using double qutoes

# %%
mystr = ''' Hello
             World''' # Define string using triple qutoes
print(mystr)
# Out:
#  Hello
#              World

# %%
mystr = """ Hello
            World""" # Define string using triple quotes
print(mystr)
# Out:
#  Hello
#             World

# %%
mystr = ('Happy '
         'Monday '
         'Everyone' )
print(mystr)
# Out:
# Happy Monday Everyone

# %%
mystr2 = 'Woohoo '
mystr2 = mystr2*5
mystr2
# Out:
# 'Woohoo Woohoo Woohoo Woohoo Woohoo '

# %%
len(mystr2) # Length of String
# Out:
# 35

# %% [markdown]
# String Indexing

# %%
str1
# Out:
# 'HELLO PYTHON'

# %%
str1[0] # First character in string "str1"
# Out:
# 'H'

# %%
str1[len(str1)-1] # Last character in string  using len function
# Out:
# 'N'

# %%
str1[-1] # Last character in string
# Out:
# 'N'

# %%
str1[6] #Fetch 7th element of the string
# Out:
# 'P'

# %%
str1[5]
# Out:
# ' '

# %% [markdown]
# String Slicing

# %%
str1[0:5] # string slicing - Fetch all characters from 0 to 5 index location
# Out:
# 'HELLO'

# %%
str1
# Out:
# 'HELLO PYTHON'

# %%
str1[6:12] # string slicing - Retrieve all characters between 6 - 12 index
# Out:
# 'PYTHON'

# %%
str1[-4:] # Retreive last four characters of the string
# Out:
# 'THON'

# %%
str1[-6:] # Retreive last six characters of the string
# Out:
# 'PYTHON'

# %%
str1[:4] # Retreive first four characters of the string
# Out:
# 'HELL'

# %%
str1[:6] # Retreive first characters of the string
# Out:
# 'HELLO '

# %% [markdown]
# Update & Delete String

# %%
str1
# Out:
# 'HELLO PYTHON'

# %%
# string are immutable which means elements of a string cannot be changed once assigned
str1[0:5] = 'HOLAA'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[212], line 2
#       1 # string are immutable which means elements of a string cannot be changed once defive
# ----> 2 str1[0:5] = 'HOLAA'
#
# TypeError: 'str' object does not support item assignment

# %%
del str1 # delete a string
print(str1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[216], line 1
# ----> 1 del str1 # delete a string
#       2 print(str1)
#
# NameError: name 'str1' is not defined

# %% [markdown]
# String concatenation

# %%
# string concatenation
s1 = "Hello "
s2 = "Asif"
s3 = s1 + s2
print(s3)
# Out:
# Hello Asif
