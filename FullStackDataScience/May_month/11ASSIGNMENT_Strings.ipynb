# %% [markdown]
# Maninpulating strings

# %% [markdown]
# Escape characters

# %% [raw]
# An escape character is created by typing a backslas '\' followed by the character you want to insert

# %%
print("Hello there! \nHow are you?\nI\'m  doing fine.")
# Out:
# Hello there!
# How are you?
# I'm  doing fine.

# %% [markdown]
# Raw strings

# %% [raw]
# A raw string entirely ignores all escape characters and prints any backslash that appears in the string.

# %%
print(r"Hello there!\nHow are you?\nI\'m doing fine.")
# Out:
# Hello there!\nHow are you?\nI\'m doing fine.

# %% [markdown]
# Multiline Strings

# %%
print(
    """ Dear Alice,

    Eve's cat has been arrested for catnapping, 
    cat burglary, and extortion.

    sincerely,
    Bob"""
)
# Out:
#  Dear Alice,
#
#     Eve's cat has been arrested for catnapping,
#     cat burglary, and extortion.
#
#     sincerely,
#     Bob

# %% [markdown]
# Indexing and Slicing strings

# %% [markdown]
# Indexing

# %%
spam = 'Hello World!'
spam[0]
# Out:
# 'H'

# %%
spam[-1]
# Out:
# '!'

# %% [markdown]
# Slicing

# %%
spam = 'Hello World!'

# %%
spam[0:5]
# Out:
# 'Hello'

# %%
spam[6:-1]
# Out:
# 'World'

# %%
spam[:-1]
# Out:
# 'Hello World'

# %%
spam[::-1]
# Out:
# '!dlroW olleH'

# %%
fizz = spam[0:5]

# %%
fizz
# Out:
# 'Hello'

# %% [markdown]
# In and not in Operators

# %%
'Hello' in 'Hello World'
# Out:
# True

# %%
'Hello' in 'Hello'
# Out:
# True

# %%
'Hello' in 'Hello World'
# Out:
# True

# %%
'HELLO' in 'Hello World'
# Out:
# False

# %%
'' in 'spam'
# Out:
# True

# %%
'cats' not in 'cats and dogs'
# Out:
# False

# %% [markdown]
# upper(), lower() and title()

# %% [raw]
# Transforms a string to upper,lower and title case:

# %%
greet = 'Hello world!'

# %%
greet.upper()
# Out:
# 'HELLO WORLD!'

# %%
print(greet)
# Out:
# Hello world!

# %%
greet.lower()
# Out:
# 'hello world!'

# %%
greet.title()
# Out:
# 'Hello World!'

# %% [markdown]
# isupper() and islower() methods

# %% [raw]
# Returns 'True' or 'False' after evaluating if a string is in upper or lower case

# %%
spam = 'Hello world!'

# %%
spam.islower()
# Out:
# False

# %%
spam.isupper()
# Out:
# False

# %%
'HELLO'.isupper()
# Out:
# True

# %%
'abc12345'.islower()
# Out:
# True

# %%
'12345'.islower()
# Out:
# False

# %%
'12345'.isupper()
# Out:
# False

# %% [markdown]
# startwith() and endswith()

# %%
'Hello world!'.startswith('Hello')
# Out:
# True

# %%
'Hello world!'.endswith('world!')
# Out:
# True

# %%
'abc123'.startswith('abcdef')
# Out:
# False

# %%
'abc123'.endswith('12')
# Out:
# False

# %%
'Hello world!'.startswith('Hel')
# Out:
# True

# %%
'Hello world!'.endswith('rld!')
# Out:
# True

# %% [markdown]
# join() and split()

# %% [markdown]
# join()

# %% [raw]
# The 'join()' method takes all the items in an iterable, like a list, dictionary, tuple or set, and join them into a string. You can also specify a separator.

# %%
''.join(['My', 'name', 'is', 'Simon'])
# Out:
# 'MynameisSimon'

# %%
', '.join(['cats', 'rats', 'bats'])
# Out:
# 'cats, rats, bats'

# %%
' '.join(['My', 'name', 'is', 'simon'])
# Out:
# 'My name is simon'

# %%
'ABC'.join(['My', 'name', 'is', 'simon'])
# Out:
# 'MyABCnameABCisABCsimon'

# %% [markdown]
# split()

# %% [raw]
# The 'split()' method splits a 'string' into a 'list'. By default, it will use whitespace to
# separate the items, but you can also set another character of choice:

# %%
'My name is Simon'.split()
# Out:
# ['My', 'name', 'is', 'Simon']

# %%
'MyABCnameABCisABCSimon'.split('ABC')
# Out:
# ['My', 'name', 'is', 'Simon']

# %%
'My name is Simon'.split('m')
# Out:
# ['My na', 'e is Si', 'on']

# %%
'My name is Simon'.split(' ')
# Out:
# ['My', 'name', 'is', 'Simon']

# %% [markdown]
# Justifying text with rjust(), ljust() and center()

# %%
'Hello'.rjust(10)
# Out:
# '     Hello'

# %%
'Hello'.rjust(20)
# Out:
# '               Hello'

# %%
'Hello World'.rjust(20)
# Out:
# '         Hello World'

# %%
'Hello'.ljust(10)
# Out:
# 'Hello     '

# %%
'Hello'.center(20)
# Out:
# '       Hello        '

# %%
'Hello'.rjust(20, '*')
# Out:
# '***************Hello'

# %%
'Hello'.ljust(20, '-')
# Out:
# 'Hello---------------'

# %%
'Hello'.center(20, '=')
# Out:
# '=======Hello========'

# %% [markdown]
# Removing whitespace with strip(), rstrip(), and lstrip()

# %%
spam = '       Hello World         '
spam.strip()
# Out:
# 'Hello World'

# %%
spam.lstrip()
# Out:
# 'Hello World         '

# %%
spam.rstrip()
# Out:
# '       Hello World'

# %%
spam= 'SpamSpamBaconSpamEggsSpamSpam'
spam.strip('ampS')
# Out:
# 'BaconSpamEggs'

# %% [markdown]
# The Count Method

# %% [raw]
# Counts the number of occurrences of a given character or substring in the string it is
# applied to. Can be optionally provided start and end index

# %%
sentence = 'one sheep two sheep three sheep four'
sentence.count('sheep')
# Out:
# 3

# %%
sentence.count('e')
# Out:
# 9

# %%
sentence.count('e',6)
# Out:
# 8

# %%
sentence.count('e', 7)
# Out:
# 7

# %% [markdown]
# Replace Method

# %% [raw]
# Replace all occurences of a given substring with another substring. Can be optionally provided a
# third argument to limit the number of replacements. Returns a new string.

# %%
text = "Hello, world!"

# %%
text.replace("world", "planet")
# Out:
# 'Hello, planet!'

# %%
fruits = "apple, banana, cherry, apple"
fruits.replace("apple", "orange", 1)
# Out:
# 'orange, banana, cherry, apple'

# %%
sentence = "I like apples, Apples are my favorite fruit"
sentence.replace("apples", "oranges")
# Out:
# 'I like oranges, Apples are my favorite fruit'
