# %% [markdown]
# ## **Matplotlib**

# %% [markdown]
# > Python have multiple option for data visualization. It has several tool which can help us to visualize the data more effectively. These Python data visulaiztion tools are as follows:
# * Matplotlib
# * Seaborn
# * pandas
# * Bokeh
# * Plotly - R PROGRAMING PACKAGE
# * ggplot - R PROGRAMING PACKAGE
# * pygal - R PROGRAMING PACKAGE

# %%
import numpy as np
import pandas as pd

# %%
# Import Matplotlib
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
x1 = np.linspace(0, 10, 50)

# create a  plot figure
# fig = plt.figure()

plt.plot(x1, np.sin(x1), '-')
plt.plot(x1, np.cos(x1), '--')
plt.show()

# %%
# The following code produces sine and cosine curves using Pyplot API.

plt.subplot(2, 1, 1)  # (rows, columns, panel number)
plt.plot(x1, np.cos(x1), '*')
plt.show()

# %%
# create a plot figure
plt.figure

# create the first of two panels and set curren axis
plt.subplot(2, 1, 1)   # (rows, columns, panel number)
plt.plot(x1, np.sin(x1))

# create the second of two panels and set current axis
plt.subplot(2, 1, 2)  # (rows, columns, panel number)
plt.plot(x1, np.cos(x1));

plt.show()

# %%
# get current figure information

print(plt.gcf())
# Out:
# Figure(640x480)

# %%
# get current axis information

print(plt.gca())
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %% [markdown]
# #### **Visualization with Pyplot**
# Generating visualization with Pyplot is very easy. The x-axis values ranges from 0-3 and
# y-axis form 1-4. if we provide a single list or array to the plot() command, matplotlib
# assumes it is sequence of y values, and automatically generates the x values.Since python
# range start with 0, the default x vector has the same length as y but starts with 0. Hence
# the x data are [0,1,2,3] and y data are [1,2,3,4].

# %%
plt.plot([1,2,3,4], [1,8,2,16])
plt.ylabel('Numbers')
plt.show()

# %% [markdown]
# #### **plot() - A versatile command**
# **plot()** is a versatile command. It will take an arbitrary number of arguments. For example, to plot x versus y. we can issue the following command:-

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3, 4], [1, 8, 27, 64])
plt.show()

# %% [markdown]
# #### **State-machine interface**
# Pyplot provides the state-machine interface to the underlying object-oriented plotting library. The state-machine implicitly and automatically creates figures and axes to achieve
# the desired plot.For example:

# %%
x = np.linspace(0, 2, 100)

plt.plot(x, x, label='linear')
plt.plot(x, x**2, label='quadratic')
plt.plot(x, x**3, label='cubic')

plt.xlabel('x label')
plt.ylabel('y label')

plt.title("Simple Plot")

plt.legend()

plt.show()

# %% [markdown]
# #### **Formatiing the style of plot**
#
# For every x, y pair of arguments, there is an optional third argument which is the format string that indicates the color and line type of the plot. The letters and symbols of the format string are from MATLAB.We can concatenate a color string with a line style string. The default format string is 'b-'. which is a solid bulue line.
# For example, to plot the above line with red circles, we would issue the following command:-

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro')
plt.axis([0, 6, 0, 20])
plt.show()

# %% [markdown]
# #### **Working with NumPy arrays**
#
# Generally, we have to work with NumPy arrays. All sequences are converted to numpy arrays internally. The below example illustrates plotting several lines with different format styles in one command using arrays.

# %%
# evenly sampled time ata 200ms intervals
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %% [markdown]
# #### **Object-Oriented API**
#
# The Object-Oriented API is available for more complex plotting situations. In Object-Oriented API the plotting functions are methods of explicit Figure and Axes object.
#
# **Figure** is the top level conatainer for all the plot elements. We can think of the **Figure** as a box-like container containing one or more **Axes**.
#
# The **Axes** represent an individual plot. The **Axes** object contain smaller objects such as axis , tick marks, lines, legends, title and text-boxes.

# %%
# First create a grid of plots
# ax will be an array of two Axes objects
fig, ax = plt.subplots(2)

# Call plot() method on the appropriate objec
ax[0].plot(x1, np.sin(x1), 'b-')
ax[1].plot(x1, np.cos(x1), 'b-');

plt.show()

# %% [markdown]
# #### **Object and Reference**
#
# The main idea with the **Object Oriented API** is to have objects that one can apply functions and actions on.
#
# We create a reference to the figure instance in the **fig** variable. Then ,we create a new axis instaces axes using the **add_axes** method in the Figure class instace fig as follows:-

# %%
fig = plt.figure()

x2 = np.linspace(0, 5, 10)
y2 = x2 ** 2

axes = fig.add_axes([0.1, 0.1, 0.8, 0.8])

axes.plot(x2, y2, 'r')

axes.set_xlabel('x2')
axes.set_ylabel('y2')
axes.set_title('title');

plt.show()

# %% [markdown]
# #### **Figure ane Axes**
#
# A figure and axes can be created as follows:
#
# fig = plt.figure()
#
# ax = plt.axes()
#
# In matplotlib, the **figure** is a single container that contains all the objects representing axes, graphics, text and labels.The **axes** is a bounding box with ticks and labels. It will conatain the plot elements tha make up the visualization.

# %%
fig = plt.figure()
ax = plt.axes()

plt.show()

# %% [markdown]
# #### **Figure and Subplots**
#
# fig = plt.figure()
#
# Now, I create one or more subplots using fig.add_subplot() as follows:-
#
# ax1 = fig.add_subplot(2,2,1)
#
# The above command means that there are four plots in total(2*2 = 4).I select the first of
# four subplots(numbered form 1)
#
# I create the next three subplots using the fig.add_subplot() commands as follows:-
#
# ax2 = fig.add_subplot(2, 2, 2)
#
# ax3 = fig.add_subplot(2, 2, 3)
#
# ax4 = fig.add_subplot(2, 2, 4)
#
# The above command result in creation of subplots.The diagrammatica representation of subplots are as follows:-

# %%
fig = plt.figure()

ax1 = fig.add_subplot(2, 2, 1)

ax2 = fig.add_subplot(2, 2, 2)

ax3 = fig.add_subplot(2, 2, 3)

ax4 = fig.add_subplot(2, 2, 4)

plt.show()

# %% [markdown]
# #### **First plot with Matplotlib**

# %%
plt.plot([1, 3, 2, 4], 'b-')
plt.show()

# %% [markdown]
# plt.plot([1, 3, 2, 4], 'b-'])
#
# This code line is the actual plotting command. Only a list of alues has been plotted that
# represent the vertical coordinates of the points to be plotted. Matplotlib will use an implicit horizontal values list, from 0 to N-1 (where N is the number of items in the list)

# %% [markdown]
# Specify both Lists

# %%
x3 = np.arange(0.0, 6.0, 0.01)

plt.plot(x3, [xi**2 for xi in x3], 'b-')

plt.show()

# %% [markdown]
# #### **Multiline Plots**
#
# Multiline Plots mean plotting more than one plot on the same figure. We can plot more than one plot one plots on the smae figure.
# It can be achieved by plotting all the lines before calling show(). It can be done as follows:-

# %%
x4 = range(1, 5)

plt.plot(x4, [xi*1.5 for xi in x4])

plt.plot(x4, [xi*3 for xi in x4])

plt.plot(x4, [xi/3.0 for xi in x4])

plt.show()

# %% [markdown]
# #### **Line Plot**

# %%
# create figure and axes first
fig = plt.figure()

ax = plt.axes()

# Declare a varibale x5
x5 = np.linspace(0, 10, 1000)

# plot the sinusoid function
ax.plot(x5, np.sin(x5), 'b-');

plt.show()

# %% [markdown]
# #### **Scatter Plot**
#
# Scatter Plot with plt.plot()
#
# We have used plt.plot/ax.plot to produce line plots.We can use the same functions to produce the scatter plots as follows:

# %%
x7 = np.linspace(0, 10, 30)

y7 = np.sin(x7)

plt.plot(x7, y7, 'o', color = 'black');

plt.show()

# %% [markdown]
# #### **Histogram**
#
# Histogram charts are a graphical display of frequecies. They are represented as bars.
#
# The **plt.hist()** function can be used to plot a simple histogram as follows:-

# %%
data1 = np.random.randn(1000)
plt.hist(data1)
plt.show()

# %% [markdown]
# #### **Bar Chart**
#
# Bar charts display rectangular bars either in vertical or horizontal form. Their length is
# proportional to the values they represent. They are used to compare two or more values.
#
# We can plot bar chart using **plt.bar()** function.

# %%
data2 = [5. ,25. , 50. , 20. ]

plt.bar(range(len(data2)), data2)
plt.show()

# %% [markdown]
# #### **Horizontal Bar Chart**
#
# We can produce Horizontal Bar Chart using the **plt.barh()** function. It is the strict equivalent to plt.bar() function.

# %%
data2 = [5. , 25. , 50. , 20. ]

plt.barh(range(len(data2)), data2)

plt.show()

# %% [markdown]
# #### **1Error Bar Chart**
#
# In experimental design, the measurements lack perfect precision. So, we have to repeat the measurements.It results in obtaining a set of values. The representation of the distribution of data values is done by plotting a single data point(known as mean value of dataset) and an error bar to represent the overall distribution of data.
#
# We can use Matplotlib's **errorbar()** function to represent the distribtion of data values. It can be done as follows:

# %%
x9 = np.arange(0, 4, 0.2)

y9 = np.exp(-x9)

e1 = 0.1 * np.abs(np.random.randn(len(y9)))

plt.errorbar(x9, y9, yerr=e1, fmt = '.-')

plt.show()

# %% [markdown]
# #### **Stacked Bar Chart**
#
# We can draw stacked bar chart by using a special parameter called **bottom** from the plt.bar() function.

# %%
A = [15. , 30. , 45. , 22. ]

B = [15. , 25. , 50. , 20. ]

z2 = range(4)

plt.bar(z2, A, color = 'b')
plt.bar(z2, B, color = 'r', bottom = A)

plt.show()

# %% [markdown]
# #### **Pie Chart**
#
# Pie charts are circular representations, divided into sectors. The sectors are also called **wedges**. The arc length of each sector is proportional to the quantity we are describing.
#
# Matplotlib provides the **pie()** function to plot pie charts from an array X. Wedges are created proprotionally so that each value x of array X generates a wedge proportional to x/sum(X).

# %%
plt.figure(figsize=(7, 7))

x10 = [35, 25, 20, 20]

labels = ['computer', 'Electronics', 'Mechanical', 'Chemical']

plt.pie(x10, labels=labels);

plt.show()

# %% [markdown]
# #### **Boxplot**
#
# Boxplot allows us to compare distributios of values by showing the median, quartiles, maximum and minimum of a set of values.
#
# We can plot a boxplot with the **boxplot()** function as follows:-

# %%
data3 = np.random.randn(100)

plt.boxplot(data3)

plt.show()

# %% [markdown]
# #### **Area Chart**
#
# An **Area Chart** is very similar to a **Line Chart**. The area between the x-axis and the line is filled in with color or shading. It represents the evolution of a numerical variable following another numerical varaible.

# %%
# create some data
x12 = range(1, 6)
y12 = [1, 4, 6, 8, 4]

# Area plot
plt.fill_between(x12, y12)
plt.show()

# %%
# I have created a basic Area chart. I could also use the stackplot function to create the 
# Area charts as follows:-

plt.stackplot(x12, y12)
plt.show()

# %% [markdown]
# #### **Contour Plot**
#
# **Contour Plots** are useful to display three-dimensional data in two dimensions using contours or color-coded regions. **Contour lines** are also known as **level lines** or **Contour lines** for a function or two varaibles are curves where the function has constant values.
#
# There are lot of applications of **Contour lines** in several fields such as meteorolgy(for temperature, pressure, rain and wind speed), geography, magnetism, engineering, social sciences and so on.
#
# The density of the lines indicates the slope of the funcition. The **gradient** of the function is always perpendicular to the contour lines. When the lines are close together, the length of the gradient is large and the variation is steep.
#
# A **Contour plot** can be created with the **plt.contour()** function as follows:

# %%
# create a matrix
matrix1 = np.random.rand(10, 20)

cp = plt.contour(matrix1)

plt.show()

# %% [markdown]
# #### **Styles with Matplotlib Plots**
#
# We can view the list of all available styles by the following command.
#
# print(plt.style.available)

# %%
# view list af all available styles

print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %% [markdown]
# We can set the **Styles** for Matplotlib plots as follows:-
#
# plt.style.use('seaborn-bright')

# %% [markdown]
# #### **Adding a grid**
#
# We can add a grid to the plot by calling the grid() function. It takes one parameter, a Boolean value, to enable(if Ture) or disable(if False) the grid.

# %%
x15 = np.arange(1, 5)

plt.plot(x15, x15*1.5, x15, x15*3.0, x15, x15/3.0)

plt.grid(True)

plt.show()

# %% [markdown]
# #### **Handling axes**
#
# We can set the axes limits with the **axis()** function as follows:-

# %%
x15 = np.arange(1, 5)

plt.plot(x15, x15*1.5, x15, x15*3.0, x15, x15/3.0)

plt.axis()    # shows the current axis llimits values

plt.axis([0, 5, -1, 13])

plt.show()

# %% [markdown]
# if we execute **axis()** without parameters, it returns the actual axis limits.
#
# We can set parameters to axis() by a list of four values.
#
# The list of four values are the keyword arguments[xmin, xmax, ymin, ymax] allows the minimum and maximum limits for X and Y axis respectively.

# %%
x15 = np.arange(1,5)

plt.plot(x15, x15*1.5, x15, x15*3.0, x15, x15/3.0)

plt.xlim(1.0, 4.0)

plt.ylim(0.0, 12.0)

plt.show()

# %% [markdown]
# #### **Handling X and Y ticks**
#
# Matplotlib provides two basics functions to manage them - **xticks()** and **yticks()**.

# %%
u = [5, 4, 9, 7, 8, 9, 6, 5, 7, 8]

plt.plot(u)

plt.xticks([2, 4, 6, 8, 10])
plt.yticks([2, 4, 6, 8, 10])

plt.show()

# %% [markdown]
# #### **Adding labels**
#
# Another important piece of inforamtion to add to a plot is the axes labels.

# %%
plt.plot([1, 3, 2, 4])

plt.xlabel('This is the X axis')

plt.ylabel('This is the Y axis')

plt.show()

# %% [markdown]
# #### **Adding a title**
#
# The title of a plot describes about the plot. Matplotlib provides a simple function **title()** to add a title to an image.

# %%
plt.plot([1, 3, 2, 4])

plt.title('First Plot')

plt.show()

# %% [markdown]
# #### **Adding a legend**
#
# Legends are used to describes what each line or curve means in the plot.
#
# Legends for curves in a figure can be added in two ways. One method is to use the **legend** method of the axis object and pass a list/tuple of legend texts as follows:

# %%
x15 = np.arange(1, 5)

fig, ax = plt.subplots()

ax.plot(x15, x15*1.5)
ax.plot(x15, x15*3.0)
ax.plot(x15, x15/3.0)

ax.legend(['Norma', 'Fast', 'Slow'])

plt.show()

# %% [markdown]
# The **legend** function takes an optional keyword argument **loc**.
# The **loc** takes numerical codes for the various places the legend can be drawn.
#
# ax.legend(loc=0) # let Matplotlib decide the otimal location
#
# ax.legend(loc=1) # upper right corner
#
# ax.legend(loc=2) # upper left corner
#
# ax.legend(loc=3) # lower left corner
#
# ax.legend(loc=4) # lower right corner
#
# ax.legend(loc=5) # right
#
# ax.legend(loc=6) # center left
#
# ax.legend(loc=7) # center right
#
# ax.legend(loc=8) # lower center
#
# ax.legend(loc=9) # upper center
#
# ax.legend(loc=10) # center

# %% [markdown]
# #### **Control colours**
#
# We can draw different lines or curves in a plot with different colours.In the code below, we specify colur as the last argument to draw red, blue, and green lines

# %%
x16 = np.arange(1,5)

plt.plot(x16, 'r')
plt.plot(x16+1, 'g')
plt.plot(x16+2, 'b')

plt.show()

# %% [markdown]
# #### **Control line styles**
#
# Matplotlib provides us different line style options to draw curves or plots. In below , i use different line styles to draw different plots.

# %%
x16 = np.arange(1, 5)

plt.plot(x16, '--', x16+1, '--', x16+2, ':')

plt.show()
