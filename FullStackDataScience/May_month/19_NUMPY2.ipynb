# %%
import numpy as np

# %%
m = np.random.randint(1,10,[4,6])
m
# Out:
# array([[4, 4, 4, 2, 6, 1],
#        [8, 6, 3, 1, 7, 6],
#        [2, 6, 6, 9, 3, 3],
#        [6, 1, 3, 3, 2, 1]])

# %%
len(m)   # gives dimension of the array
# Out:
# 4

# %%
m.shape  # dimension of the array
# Out:
# (4, 6)

# %%
arr = np.arange(6)
arr
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
arr.reshape(2,3)
# Out:
# array([[0, 1, 2],
#        [3, 4, 5]])

# %%
arr.reshape(4,2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 arr.reshape(4,2)
#
# ValueError: cannot reshape array of size 6 into shape (4,2)

# %%
arr.reshape(1,6)
# Out:
# array([[0, 1, 2, 3, 4, 5]])

# %%
arr.reshape(6,1)
# Out:
# array([[0],
#        [1],
#        [2],
#        [3],
#        [4],
#        [5]])

# %%
m
# Out:
# array([[4, 4, 4, 2, 6, 1],
#        [8, 6, 3, 1, 7, 6],
#        [2, 6, 6, 9, 3, 3],
#        [6, 1, 3, 3, 2, 1]])

# %%
m[2,4]
# Out:
# 3

# %%
m[2:4]
# Out:
# array([[2, 6, 6, 9, 3, 3],
#        [6, 1, 3, 3, 2, 1]])

# %% [markdown]
# How to Print column

# %%
m
# Out:
# array([[4, 4, 4, 2, 6, 1],
#        [8, 6, 3, 1, 7, 6],
#        [2, 6, 6, 9, 3, 3],
#        [6, 1, 3, 3, 2, 1]])

# %%
m[:,0]
# Out:
# array([4, 8, 2, 6])

# %%
m[:,-3]
# Out:
# array([2, 1, 9, 3])

# %%
m1 = np.random.randint(1,10,[9,9])

# %%
m1
# Out:
# array([[2, 4, 4, 2, 2, 8, 2, 1, 1],
#        [2, 8, 8, 4, 9, 1, 4, 9, 2],
#        [4, 1, 2, 7, 2, 7, 8, 7, 3],
#        [8, 7, 9, 7, 3, 4, 9, 1, 5],
#        [9, 4, 6, 8, 4, 4, 1, 1, 1],
#        [4, 4, 1, 1, 7, 6, 1, 2, 8],
#        [7, 3, 6, 4, 9, 1, 8, 4, 3],
#        [9, 3, 2, 4, 7, 2, 7, 7, 2],
#        [4, 6, 4, 8, 6, 2, 1, 9, 9]])

# %%
m1[1:4, 1:3]
# Out:
# array([[8, 8],
#        [1, 2],
#        [7, 9]])

# %%
m1
# Out:
# array([[2, 4, 4, 2, 2, 8, 2, 1, 1],
#        [2, 8, 8, 4, 9, 1, 4, 9, 2],
#        [4, 1, 2, 7, 2, 7, 8, 7, 3],
#        [8, 7, 9, 7, 3, 4, 9, 1, 5],
#        [9, 4, 6, 8, 4, 4, 1, 1, 1],
#        [4, 4, 1, 1, 7, 6, 1, 2, 8],
#        [7, 3, 6, 4, 9, 1, 8, 4, 3],
#        [9, 3, 2, 4, 7, 2, 7, 7, 2],
#        [4, 6, 4, 8, 6, 2, 1, 9, 9]])

# %%
m1[3:8, 3:8]
# Out:
# array([[7, 3, 4, 9, 1],
#        [8, 4, 4, 1, 1],
#        [1, 7, 6, 1, 2],
#        [4, 9, 1, 8, 4],
#        [4, 7, 2, 7, 7]])

# %% [markdown]
# Masking or filter in matrix

# %%
type(m1)
# Out:
# numpy.ndarray

# %%
m1 < 5
# Out:
# array([[ True,  True,  True,  True,  True, False,  True,  True,  True],
#        [ True, False, False,  True, False,  True,  True, False,  True],
#        [ True,  True,  True, False,  True, False, False, False,  True],
#        [False, False, False, False,  True,  True, False,  True, False],
#        [False,  True, False, False,  True,  True,  True,  True,  True],
#        [ True,  True,  True,  True, False, False,  True,  True, False],
#        [False,  True, False,  True, False,  True, False,  True,  True],
#        [False,  True,  True,  True, False,  True, False, False,  True],
#        [ True, False,  True, False, False,  True,  True, False, False]])

# %%
m1[m1 < 5]
# Out:
# array([2, 4, 4, 2, 2, 2, 1, 1, 2, 4, 1, 4, 2, 4, 1, 2, 2, 3, 3, 4, 1, 4,
#        4, 4, 1, 1, 1, 4, 4, 1, 1, 1, 2, 3, 4, 1, 4, 3, 3, 2, 4, 2, 2, 4,
#        4, 2, 1])

# %%
m1[m1<=5]
# Out:
# array([2, 4, 4, 2, 2, 2, 1, 1, 2, 4, 1, 4, 2, 4, 1, 2, 2, 3, 3, 4, 1, 5,
#        4, 4, 4, 1, 1, 1, 4, 4, 1, 1, 1, 2, 3, 4, 1, 4, 3, 3, 2, 4, 2, 2,
#        4, 4, 2, 1])

# %%
m1[m1 != 5]
# Out:
# array([2, 4, 4, 2, 2, 8, 2, 1, 1, 2, 8, 8, 4, 9, 1, 4, 9, 2, 4, 1, 2, 7,
#        2, 7, 8, 7, 3, 8, 7, 9, 7, 3, 4, 9, 1, 9, 4, 6, 8, 4, 4, 1, 1, 1,
#        4, 4, 1, 1, 7, 6, 1, 2, 8, 7, 3, 6, 4, 9, 1, 8, 4, 3, 9, 3, 2, 4,
#        7, 2, 7, 7, 2, 4, 6, 4, 8, 6, 2, 1, 9, 9])

# %%
m1[m1 == 5]
# Out:
# array([5])

# %%
m1[m1 >= 5]
# Out:
# array([8, 8, 8, 9, 9, 7, 7, 8, 7, 8, 7, 9, 7, 9, 5, 9, 6, 8, 7, 6, 8, 7,
#        6, 9, 8, 9, 7, 7, 7, 6, 8, 6, 9, 9])

# %% [markdown]
# image analysis using np, pil

# %%
import matplotlib.pyplot as plt

# %%
from PIL import Image  # Python imageing library

# %%
ele_img = Image.open("D:\elephant.jpg")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\e'
# <>:1: SyntaxWarning: invalid escape sequence '\e'
# C:\Users\ACER\AppData\Local\Temp\ipykernel_10228\4104993721.py:1: SyntaxWarning: invalid escape sequence '\e'
#   ele_img = Image.open("D:\elephant.jpg")

# %%
ele_img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x960>

# %%
type(ele_img)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
ele_arr = np.asarray(ele_img)
ele_arr
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 ele_arr = np.asarray(ele_img)
#       2 ele_arr
#
# NameError: name 'np' is not defined

# %%
plt.imshow(ele_img)
