# %% [markdown]
# Import math module

# %%
x = sqrt(25) # sqrt is inbuild function
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 x = sqrt(25)
#
# NameError: name 'sqrt' is not defined

# %%
import math # math is module

x = math.sqrt(25)
x
# Out:
# 5.0

# %%
x1 = math.sqrt(15)
x1
# Out:
# 3.872983346207417

# %%
print(math.floor(2.9)) #floor - minimum or least value
# Out:
# 2

# %%
print(math.ceil(2.9)) #ceil - maximum or highest value
# Out:
# 3

# %%
print(math.pow(3,2))
# Out:
# 9.0

# %%
print(math.pi) # these are constant
# Out:
# 3.141592653589793

# %%
print(math.e) # these are constant
# Out:
# 2.718281828459045

# %%
import math as m
m.sqrt(10)
# Out:
# 3.1622776601683795

# %%
from math import sqrt,pow # math has many function if you want to call specific function then use from
pow(2,3)
# Out:
# 8.0

# %%
round(pow(2,3))
# Out:
# 8

# %%
help()
# Out:
# Welcome to Python 3.12's help utility! If this is your first time using
# Python, you should definitely check out the tutorial at
# https://docs.python.org/3.12/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To get a list of available
# modules, keywords, symbols, or topics, enter "modules", "keywords",
# "symbols", or "topics".
#
# Each module also comes with a one-line summary of what it does; to list
# the modules whose name or summary contain a given string such as "spam",
# enter "modules spam".
#
# To quit this help utility and return to the interpreter,
# enter "q" or "quit".
# help>  q
# You are now leaving help and returning to the Python interpreter.
# If you want to ask for help on a particular object directly from the
# interpreter, you can type "help(object)".  Executing "help('string')"
# has the same effect as typing a particular string at the help> prompt.

# %% [markdown]
# user input function in python || command line input

# %%
x = input()
y = input()
z = x + y 
print(z) # console is waiting for user to enter input
# also if your work in idle
# Out:
#  10
#  20
# 1020

# %%
x1 = input('Enter the 1st number') # whenever you works in input function it always gives you string
y1 = input('Enter the 2nd number') # it won't understand as arithmetic operator
z1 = x1 + y1
print(z1)
# Out:
# Enter the 1st number 39
# Enter the 2nd number 42
# 3942

# %%
type(x1)
# Out:
# str

# %%
type(y1)
# Out:
# str

# %%
x1 = input('Enter the 1st number') #whenever you works in input function it always gives you string
a1 = int(x1)
y1 = input('Enter the 2nd number') # it won't understand as arithmetic operator
b1 = int(y1)
z1 = a1 + b1
print(z1)
# Out:
# Enter the 1st number 22
# Enter the 2nd number 31
# 53

# %% [markdown]
# for the above code notice we are using many lines because for that wasting some memory spaces as well

# %%
x2 = int(input('Enter the 1st number'))
y2 = int(input('Enter the 2nd number'))
z2 = x2 + y2
z2
# Out:
# Enter the 1st number 42
# Enter the 2nd number 32
# 74

# %% [markdown]
# Lets take input form the user in char format, but we dont habe char format in python

# %%
ch = input('Enter a char')
print(ch)
# Out:
# Enter a char hello world
# hello world

# %%
print(ch[0])
# Out:
# h

# %%
print(ch[1])
# Out:
# e

# %%
print(ch[-1])
# Out:
# d

# %%
print(ch[-5:-1])
# Out:
# worl

# %%
ch = input('enter a char')
print(ch) # if you enter as 2 + 6 -1 we get output as 2 + 6-1 only
# Out:
# enter a char 2 + 6 -1
# 2 + 6 -1

# %%
result = eval(input('enter an expr'))
print(result)
# Out:
# enter an expr 2 + 6 -1
# 7
